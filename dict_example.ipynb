# %%
tel = {'jack':4098, 'sape':4139}

# %%
tel
# Out:
# {'jack': 4098, 'sape': 4139}

# %%
tel['guido']=8080

# %%
tel
# Out:
# {'jack': 4098, 'sape': 4139, 'guido': 8080}

# %%
tel['jack']
# Out:
# 4098

# %%
tel['abc']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 tel['abc']
#
# KeyError: 'abc'

# %%
tel.get('abc')

# %%
print(tel.get('abc'))
# Out:
# None

# %%
print(tel.get('sape'))
# Out:
# 4139

# %%
list(tel)
# Out:
# ['jack', 'sape', 'guido']
